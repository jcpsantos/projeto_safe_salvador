# %% [markdown]
# <center><h1 style="color: #f44336;">Analise de Dados da Criminalidade em Salvador</h1></center>

# %% [markdown]
# <p> A violência no Brasil é um problema persistente que atinge direta ou indiretamente a população. O país tem níveis acima da média mundial no que se refere a crimes violentos, com níveis particularmente altos no tocante a violência armada e homicídios. Em 2016, o Brasil alcançou a marca histórica de 62 517 homicídios, segundo informações do Ministério da Saúde. Isso equivale a uma taxa de 30,3 mortes para cada 100 mil habitantes, uma das mais altas taxas de homicídios intencionais do mundo.O limite considerado como suportável pela Organização Mundial da Saúde (OMS) é de 10 homicídios por 100 mil habitantes.</p>
# fonte: <a href='https://pt.wikipedia.org/wiki/Viol%C3%AAncia_no_Brasil'>Wikipedia</a>

# %% [markdown]
# <h2 style="color: #f44336;">Origem da base de dados</h2>

# %% [markdown]
# <p>Essa base de dados,tem sua origem no site da Secretaria de Segurança Pública, possuimos aqui amostra de crimes que aconteceram em Salvador de Janeiro de 2014 até Março de 2018. Com base nas informações dessa base de dados, irei levantar questionamentos e responde-los</p>
# <ul>
#     <li><a href='http://www.ssp.ba.gov.br/modules/conteudo/conteudo.php?conteudo=36'>SSP-BA Estatística 2014</a></li>
#     <li><a href='http://www.ssp.ba.gov.br/modules/conteudo/conteudo.php?conteudo=21'>SSP-BA Estatística 2015</a></li>
#     <li><a href='http://www.ssp.ba.gov.br/modules/conteudo/conteudo.php?conteudo=69'>SSP-BA Estatística 2016</a></li>
#     <li><a href='http://www.ssp.ba.gov.br/modules/conteudo/conteudo.php?conteudo=90'>SSP-BA Estatística 2017</a></li>
#     <li><a href='http://www.ssp.ba.gov.br/modules/conteudo/conteudo.php?conteudo=97'>SSP-BA Estatística 2018</a></li>
# </ul>

# %% [markdown]
# **Vamos importar as bibliotecas necessárias converter os arquivos pdf em csv e carregar os arquivos csv e investigar os dados**

# %%
#-> Importando bibliotecas necessárias 
import pdftables_api as pdf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

# %%
# Função para converter os arquivos pdf em csv
def converter(input_pdf, output_csv):
    """Converter tabelas PDF em tabelas CSV
      Argumentos:
          input_pdf: arquivo/tabela em PDF.
          output_csv: saída do aquivo em CSV.
      Retorna:
          Um arquivo/tabela no formato CSV"""
    c = pdf.Client('qxppgsjih80k')
    c.csv(input_pdf, output_csv)

# %%
#Ativando a função de conversão
converter('03CAPITAL2014.pdf', '2014.csv')
converter('03CAPITAL2015.pdf', '2015.csv')
converter('03CAPITAL2016.pdf', '2016.csv')
converter('03_CAPITAL_2017_JAN_A_DEZ.pdf', '2017.csv')
converter('03_CAPITAL_2018_JAN_A_MAR.pdf', '2018.csv')

# %%
#Carregando o arquivo de dados
ds2014 = pd.read_csv('2014.csv')
ds2015 = pd.read_csv('2015.csv')
ds2016 = pd.read_csv('2016.csv')
ds2017 = pd.read_csv('2017.csv')
ds2018 = pd.read_csv('2018.csv')

#Verificando os dados carregados de 2014
ds2014
# Out:
#                 SECRETARIA DA SEGURANÇA PÚBLICA Unnamed: 1      Unnamed: 2  \
# 0                  PRINCIPAIS DELITOS - CAPITAL        NaN             NaN
# 1              Período: 01/01/2014 à 31/12/2014        NaN             NaN
# 2                                           NaN        NaN             NaN
# 3                                           NaN        NaN  Lesão Corporal
# 4                   Área Integrada de Segurança  Homicídio             NaN
# 5                                           NaN        NaN      Seguida de
# 6                                Pública - AISP     Doloso             NaN
# 7                                           NaN        NaN           Morte
# 8                                           NaN        NaN             NaN
# 9                              AISP 06 - Brotas         69               0
# 10                       AISP 07 - Rio Vermelho         18               2
# 11                        AISP 09 - Boca do Rio         16               1
# 12                             AISP 12 - Itapuã        152               2
# 13                              AISP 14 - Barra          4               1
# 14                           AISP 15 - Nordeste         15               0
# 15                             AISP 16 - Pituba          7               0
# 16                               RISP ATLÂNTICO        281               6
# 17                             AISP 01 - Barris         36               1
# 18                          AISP 02 - Liberdade        124               3
# 19                             AISP 03 - Bonfim         83               3
# 20                        AISP 04 - São Caetano        124               2
# 21                           AISP 05 - Periperi        235               5
# 22                                AISP 08 - CIA         29               0
# 23                                     RISP BTS        631              14
# 24                        AISP 10 - Pau da Lima        108               2
# 25                     AISP 11 - Tancredo Neves        200               3
# 26                         AISP 13 - Cajazeiras        101               1
# 27                                 RISP CENTRAL        409               6
# 28                             TOTAL DA CAPITAL      1.321              26
# 29                                Fonte: SSP-BA        NaN             NaN
# 30  * Dados coletados em 09/10/2015 às 09h30min        NaN             NaN
#
#          Unnamed: 3    Unnamed: 4 Unnamed: 5      Unnamed: 6 Unnamed: 7  \
# 0               NaN           NaN        NaN             NaN        NaN
# 1               NaN           NaN        NaN             NaN        NaN
# 2               NaN           NaN        NaN             NaN        NaN
# 3         Roubo com           NaN        NaN  Roubo a Ônibus        NaN
# 4               NaN  Tentativa de        NaN             NaN   Roubo de
# 5   Resultado Morte           NaN    Estupro    (Urbano e em        NaN
# 6               NaN     Homicídio        NaN             NaN    Veículo
# 7    - (Latrocínio)           NaN        NaN        Rodovia)        NaN
# 8               NaN           NaN        NaN             NaN        NaN
# 9                 4            43         21             205        568
# 10                3            13         21             106        287
# 11                1            12         13              57        562
# 12                8            44         62             168        832
# 13                0             1          5              33         80
# 14                0             6         12              61         20
# 15                0            10          7             114        358
# 16               16           129        141             744      2.707
# 17                4            18         22             107        291
# 18                3            56         35              93        545
# 19                3            54         27             125        372
# 20                7            26         55             149        431
# 21                6           156         82             175        395
# 22                1             7          6              12        147
# 23               24           317        227             661      2.181
# 24                4            64         35             147        533
# 25                5           125         86             333        713
# 26                1            77         43              44        239
# 27               10           266        164             524      1.485
# 28               50           712        532           1.929      6.373
# 29              NaN           NaN        NaN             NaN        NaN
# 30              NaN           NaN        NaN             NaN        NaN
#
#           Unnamed: 8    Unnamed: 9
# 0                NaN           NaN
# 1                NaN           NaN
# 2                NaN     Uso/Porte
# 3                NaN           NaN
# 4                NaN    Substância
# 5   Furto de Veículo           NaN
# 6                NaN  Entorpecente
# 7                NaN           NaN
# 8                NaN    (Usuários)
# 9                150            74
# 10                63           107
# 11                64            24
# 12               234           132
# 13                28            35
# 14                 7            33
# 15                38            31
# 16               584           436
# 17               120           119
# 18               191            56
# 19               246            65
# 20                85            37
# 21                70            52
# 22                22             9
# 23               734           338
# 24               160            35
# 25               219           103
# 26                55            18
# 27               434           156
# 28             1.752           930
# 29               NaN           NaN
# 30               NaN           NaN

# %%
#Verificando os dados carregados de 2015, 2016, 2017 e 2018
print(ds2015.head())
print(ds2016.head())
print(ds2017.head())
print(ds2018.head())
# Out:
#     SECRETARIA DA SEGURANÇA PÚBLICA Unnamed: 1      Unnamed: 2 Unnamed: 3  \
# 0      PRINCIPAIS DELITOS - CAPITAL        NaN             NaN        NaN
# 1  Período: 01/01/2015 à 31/12/2015        NaN             NaN        NaN
# 2                               NaN        NaN             NaN        NaN
# 3                               NaN        NaN  Lesão Corporal  Roubo com
# 4       Área Integrada de Segurança  Homicídio             NaN        NaN
#
#      Unnamed: 4 Unnamed: 5      Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0           NaN        NaN             NaN        NaN        NaN         NaN
# 1           NaN        NaN             NaN        NaN        NaN         NaN
# 2           NaN        NaN             NaN        NaN        NaN   Uso/Porte
# 3           NaN        NaN  Roubo a Ônibus        NaN        NaN         NaN
# 4  Tentativa de        NaN             NaN   Roubo de        NaN  Substância
#     SECRETARIA DA SEGURANÇA PÚBLICA Unnamed: 1      Unnamed: 2 Unnamed: 3  \
# 0      PRINCIPAIS DELITOS - CAPITAL        NaN             NaN        NaN
# 1  Período: 01/01/2016 à 31/12/2016        NaN             NaN        NaN
# 2                               NaN        NaN             NaN        NaN
# 3                               NaN        NaN  Lesão Corporal  Roubo com
# 4       Área Integrada de Segurança  Homicídio             NaN        NaN
#
#      Unnamed: 4 Unnamed: 5      Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0           NaN        NaN             NaN        NaN        NaN         NaN
# 1           NaN        NaN             NaN        NaN        NaN         NaN
# 2           NaN        NaN             NaN        NaN        NaN   Uso/Porte
# 3           NaN        NaN  Roubo a Ônibus        NaN        NaN         NaN
# 4  Tentativa de        NaN             NaN   Roubo de        NaN  Substância
#     SECRETARIA DA SEGURANÇA PÚBLICA Unnamed: 1      Unnamed: 2 Unnamed: 3  \
# 0      PRINCIPAIS DELITOS - CAPITAL        NaN             NaN        NaN
# 1  Período: 01/01/2017 à 31/12/2017        NaN             NaN        NaN
# 2                               NaN        NaN             NaN        NaN
# 3                               NaN        NaN  Lesão Corporal  Roubo com
# 4       Área Integrada de Segurança  Homicídio             NaN        NaN
#
#      Unnamed: 4 Unnamed: 5      Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0           NaN        NaN             NaN        NaN        NaN         NaN
# 1           NaN        NaN             NaN        NaN        NaN         NaN
# 2           NaN        NaN             NaN        NaN        NaN   Uso/Porte
# 3           NaN        NaN  Roubo a Ônibus        NaN        NaN         NaN
# 4  Tentativa de        NaN             NaN   Roubo de        NaN  Substância
#     SECRETARIA DA SEGURANÇA PÚBLICA Unnamed: 1      Unnamed: 2 Unnamed: 3  \
# 0      PRINCIPAIS DELITOS - CAPITAL        NaN             NaN        NaN
# 1  Período: 01/01/2018 à 31/03/2018        NaN             NaN        NaN
# 2                               NaN        NaN             NaN        NaN
# 3                               NaN        NaN  Lesão Corporal  Roubo com
# 4       Área Integrada de Segurança  Homicídio             NaN        NaN
#
#      Unnamed: 4 Unnamed: 5      Unnamed: 6 Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0           NaN        NaN             NaN        NaN        NaN         NaN
# 1           NaN        NaN             NaN        NaN        NaN         NaN
# 2           NaN        NaN             NaN        NaN        NaN   Uso/Porte
# 3           NaN        NaN  Roubo a Ônibus        NaN        NaN         NaN
# 4  Tentativa de        NaN             NaN   Roubo de        NaN  Substância

# %%
#Avaliando os dados 2014
ds2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
# SECRETARIA DA SEGURANÇA PÚBLICA    26 non-null object
# Unnamed: 1                         22 non-null object
# Unnamed: 2                         23 non-null object
# Unnamed: 3                         23 non-null object
# Unnamed: 4                         22 non-null object
# Unnamed: 5                         21 non-null object
# Unnamed: 6                         23 non-null object
# Unnamed: 7                         22 non-null object
# Unnamed: 8                         21 non-null object
# Unnamed: 9                         24 non-null object
# dtypes: object(10)
# memory usage: 2.5+ KB

# %%
#Avaliando os dados 2018
ds2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 10 columns):
# SECRETARIA DA SEGURANÇA PÚBLICA    26 non-null object
# Unnamed: 1                         22 non-null object
# Unnamed: 2                         23 non-null object
# Unnamed: 3                         23 non-null object
# Unnamed: 4                         22 non-null object
# Unnamed: 5                         21 non-null object
# Unnamed: 6                         23 non-null object
# Unnamed: 7                         22 non-null object
# Unnamed: 8                         21 non-null object
# Unnamed: 9                         24 non-null object
# dtypes: object(10)
# memory usage: 2.5+ KB

# %%
#numero de amostras  (linhas e colunas)
def amostras(ds, ano):
    """Mostra os valores de amostras e colunas do arquivo
      Argumentos:
          ds: Lista/base de dados.
          ano: Ano do arquivo
      Retorna:
          Um print informando os valores de amostras e colunas do arquivo."""
    print("O arquivo {0} possui {1} amostras e {2} colunas".format(
        ano, ds.shape[0], ds.shape[1] ))
amostras(ds2014, 2014)
amostras(ds2015, 2015)
amostras(ds2016, 2016)
amostras(ds2017, 2017)
amostras(ds2018, 2018)
# Out:
# O arquivo 2014 possui 31 amostras e 10 colunas
# O arquivo 2015 possui 31 amostras e 10 colunas
# O arquivo 2016 possui 31 amostras e 10 colunas
# O arquivo 2017 possui 31 amostras e 10 colunas
# O arquivo 2018 possui 31 amostras e 10 colunas

# %%
#Colunas com valores faltantes 2014
print("Colunas com valores Faltantes: \n {0} \n".format(
    ds2014.columns[ds2014.isnull().any()].values))
# Out:
# Colunas com valores Faltantes:
#  ['SECRETARIA DA SEGURANÇA PÚBLICA' 'Unnamed: 1' 'Unnamed: 2' 'Unnamed: 3'
#  'Unnamed: 4' 'Unnamed: 5' 'Unnamed: 6' 'Unnamed: 7' 'Unnamed: 8'
#  'Unnamed: 9']

# %%
#linhas duplicadas 2014
print(" Duplicadas: {0} ".format(
        ds2014.duplicated().sum()))

#linhas duplicadas 2018
print(" Duplicadas: {0} ".format(
        ds2018.duplicated().sum()))
# Out:
#  Duplicadas: 0
#  Duplicadas: 0

# %%
#Verificando a quantidade de valores unicos em cada coluna 2014
ds2014.nunique()
# Out:
# SECRETARIA DA SEGURANÇA PÚBLICA    26
# Unnamed: 1                         21
# Unnamed: 2                         11
# Unnamed: 3                         15
# Unnamed: 4                         22
# Unnamed: 5                         19
# Unnamed: 6                         23
# Unnamed: 7                         22
# Unnamed: 8                         21
# Unnamed: 9                         23
# dtype: int64

# %%
#Verificando a quantidade de valores unicos em cada coluna 2015
ds2015.nunique()
# Out:
# SECRETARIA DA SEGURANÇA PÚBLICA    26
# Unnamed: 1                         21
# Unnamed: 2                         13
# Unnamed: 3                         14
# Unnamed: 4                         20
# Unnamed: 5                         18
# Unnamed: 6                         23
# Unnamed: 7                         22
# Unnamed: 8                         19
# Unnamed: 9                         22
# dtype: int64

# %%
#Verificando a quantidade de valores unicos em cada coluna 2016
ds2016.nunique()
# Out:
# SECRETARIA DA SEGURANÇA PÚBLICA    26
# Unnamed: 1                         21
# Unnamed: 2                         11
# Unnamed: 3                         14
# Unnamed: 4                         22
# Unnamed: 5                         17
# Unnamed: 6                         23
# Unnamed: 7                         22
# Unnamed: 8                         21
# Unnamed: 9                         22
# dtype: int64

# %%
#Verificando a quantidade de valores unicos em cada coluna 2017
ds2017.nunique()
# Out:
# SECRETARIA DA SEGURANÇA PÚBLICA    26
# Unnamed: 1                         20
# Unnamed: 2                          9
# Unnamed: 3                         13
# Unnamed: 4                         21
# Unnamed: 5                         19
# Unnamed: 6                         23
# Unnamed: 7                         22
# Unnamed: 8                         21
# Unnamed: 9                         22
# dtype: int64

# %%
#Verificando a quantidade de valores unicos em cada coluna 2018
ds2018.nunique()
# Out:
# SECRETARIA DA SEGURANÇA PÚBLICA    26
# Unnamed: 1                         19
# Unnamed: 2                          5
# Unnamed: 3                          6
# Unnamed: 4                         16
# Unnamed: 5                         14
# Unnamed: 6                         19
# Unnamed: 7                         22
# Unnamed: 8                         17
# Unnamed: 9                         22
# dtype: int64

# %% [markdown]
# **Agora que já conhecemos os nossos dados vamos a próxima etapa.**

# %% [markdown]
# <h2 style="color: #f44336;">Limpeza dos dados</h2>

# %%
# Excluindo as linhas com valores nulos
ds2014 = ds2014.dropna(axis=0)
ds2015 = ds2015.dropna(axis=0)
ds2016 = ds2016.dropna(axis=0)
ds2017 = ds2017.dropna(axis=0)
ds2018 = ds2018.dropna(axis=0)

# %%
#Vamos verificar como ficou a tabela de 2014
ds2014.head()
# Out:
#    SECRETARIA DA SEGURANÇA PÚBLICA Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 9                 AISP 06 - Brotas         69          0          4
# 10          AISP 07 - Rio Vermelho         18          2          3
# 11           AISP 09 - Boca do Rio         16          1          1
# 12                AISP 12 - Itapuã        152          2          8
# 13                 AISP 14 - Barra          4          1          0
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9
# 9          43         21        205        568        150         74
# 10         13         21        106        287         63        107
# 11         12         13         57        562         64         24
# 12         44         62        168        832        234        132
# 13          1          5         33         80         28         35

# %%
#Agora vamos melhora os nomes das colunas
new_labels = ['aisp', 'homicídio doloso', 'lesão corporal seguida de morte', 'latrocínio', 'tentativa de homicídio', 'estupro', 'roubo a ônibus', 'roubo de veículo', 'furto de veículo', 'uso/porte substância entorpecente ']
#Função para novos nomes nas colunas
def name_columns(df):
    """Incluir novas labels nas colunas
      Argumentos:
          df: Lista/base de dados.
      Retorna:
          Lista/base de dados."""
    df.columns = new_labels

# %%
name_columns(ds2014)
name_columns(ds2015)
name_columns(ds2016)
name_columns(ds2017)
name_columns(ds2018)

# %%
#Verificando se as alterações foram realizadas
ds2015.head()
# Out:
#                       aisp homicídio doloso lesão corporal seguida de morte  \
# 9         AISP 06 - Brotas               60                               3
# 10  AISP 07 - Rio Vermelho               24                               1
# 11   AISP 09 - Boca do Rio               25                               1
# 12        AISP 12 - Itapuã              119                               3
# 13         AISP 14 - Barra                2                               1
#
#    latrocínio tentativa de homicídio estupro roubo a ônibus roubo de veículo  \
# 9           5                     22      31            190              493
# 10          1                     33      18            153              241
# 11          4                     25      31             49              596
# 12          6                     18      49            218              871
# 13          2                      4       9             28               82
#
#    furto de veículo uso/porte substância entorpecente
# 9               133                                 77
# 10               58                                 41
# 11               67                                 90
# 12              189                                 79
# 13               14                                 47

# %%
#Vamos verificar se tem açguma coluna com valores faltantes
print("Colunas com valores Faltantes: \n {0} \n".format(
    ds2016.columns[ds2016.isnull().any()].values))
# Out:
# Colunas com valores Faltantes:
#  []

# %%
#Criando colunas do ano
# Criando vetor de ano para o dataframe
def ano_vetor(ano, ds):
    """Realizar uma lista com valores do ano
      Argumentos:
          ano: Valor do ano a ser incluído.
          ds: Lista/base de dados
      Retorna:
          Vetor/Lista com os valores do ano desejado."""
    x_ano = np.repeat(ano, ds.shape[0])
    return x_ano

ano_2014=ano_vetor(2014, ds2014)
print(ano_2014)

ano_2015=ano_vetor(2015, ds2015)
print(ano_2015)

ano_2016=ano_vetor(2016, ds2016)
print(ano_2016)

ano_2017=ano_vetor(2017, ds2017)
print(ano_2017)

ano_2018=ano_vetor(2018, ds2018)
print(ano_2018)
# Out:
# [2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014 2014
#  2014 2014 2014 2014 2014 2014]
# [2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015 2015
#  2015 2015 2015 2015 2015 2015]
# [2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016 2016
#  2016 2016 2016 2016 2016 2016]
# [2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017 2017
#  2017 2017 2017 2017 2017 2017]
# [2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018 2018
#  2018 2018 2018 2018 2018 2018]

# %%
#Adicionando os vetores a nova coluna de Ano
ds2014['ano'] = ano_2014
ds2015['ano'] = ano_2015
ds2016['ano'] = ano_2016
ds2017['ano'] = ano_2017
ds2018['ano'] = ano_2018
ds2014.head()
# Out:
# C:\Users\JuanCaio\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                       aisp homicídio doloso lesão corporal seguida de morte  \
# 9         AISP 06 - Brotas               69                               0
# 10  AISP 07 - Rio Vermelho               18                               2
# 11   AISP 09 - Boca do Rio               16                               1
# 12        AISP 12 - Itapuã              152                               2
# 13         AISP 14 - Barra                4                               1
#
#    latrocínio tentativa de homicídio estupro roubo a ônibus roubo de veículo  \
# 9           4                     43      21            205              568
# 10          3                     13      21            106              287
# 11          1                     12      13             57              562
# 12          8                     44      62            168              832
# 13          0                      1       5             33               80
#
#    furto de veículo uso/porte substância entorpecente    ano
# 9               150                                 74  2014
# 10               63                                107  2014
# 11               64                                 24  2014
# 12              234                                132  2014
# 13               28                                 35  2014

# %%
#Combinndo os dataframes em um só
ds_total = ds2014.append(ds2015)
ds_total = ds_total.append(ds2016)
ds_total = ds_total.append(ds2017)
ds_total = ds_total.append(ds2018)

ds_total
# Out:
#                         aisp homicídio doloso lesão corporal seguida de morte  \
# 9           AISP 06 - Brotas               69                               0
# 10    AISP 07 - Rio Vermelho               18                               2
# 11     AISP 09 - Boca do Rio               16                               1
# 12          AISP 12 - Itapuã              152                               2
# 13           AISP 14 - Barra                4                               1
# 14        AISP 15 - Nordeste               15                               0
# 15          AISP 16 - Pituba                7                               0
# 16            RISP ATLÂNTICO              281                               6
# 17          AISP 01 - Barris               36                               1
# 18       AISP 02 - Liberdade              124                               3
# 19          AISP 03 - Bonfim               83                               3
# 20     AISP 04 - São Caetano              124                               2
# 21        AISP 05 - Periperi              235                               5
# 22             AISP 08 - CIA               29                               0
# 23                  RISP BTS              631                              14
# 24     AISP 10 - Pau da Lima              108                               2
# 25  AISP 11 - Tancredo Neves              200                               3
# 26      AISP 13 - Cajazeiras              101                               1
# 27              RISP CENTRAL              409                               6
# 28          TOTAL DA CAPITAL            1.321                              26
# 9           AISP 06 - Brotas               60                               3
# 10    AISP 07 - Rio Vermelho               24                               1
# 11     AISP 09 - Boca do Rio               25                               1
# 12          AISP 12 - Itapuã              119                               3
# 13           AISP 14 - Barra                2                               1
# 14        AISP 15 - Nordeste               10                               2
# 15          AISP 16 - Pituba                2                               0
# 16            RISP ATLÂNTICO              242                              11
# 17          AISP 01 - Barris               53                               1
# 18       AISP 02 - Liberdade              110                               2
# ..                       ...              ...                             ...
# 19          AISP 03 - Bonfim               91                               1
# 20     AISP 04 - São Caetano              131                               1
# 21        AISP 05 - Periperi              243                               0
# 22             AISP 08 - CIA               34                               1
# 23                  RISP BTS              651                               7
# 24     AISP 10 - Pau da Lima              128                               1
# 25  AISP 11 - Tancredo Neves              135                               1
# 26      AISP 13 - Cajazeiras              128                               0
# 27              RISP CENTRAL              391                               2
# 28          TOTAL DA CAPITAL            1.346                              12
# 9           AISP 06 - Brotas               17                               0
# 10    AISP 07 - Rio Vermelho                3                               0
# 11     AISP 09 - Boca do Rio                9                               0
# 12          AISP 12 - Itapuã               30                               0
# 13           AISP 14 - Barra                1                               0
# 14        AISP 15 - Nordeste                7                               0
# 15          AISP 16 - Pituba                1                               0
# 16            RISP ATLÂNTICO               68                               0
# 17          AISP 01 - Barris                8                               0
# 18       AISP 02 - Liberdade               37                               0
# 19          AISP 03 - Bonfim               24                               0
# 20     AISP 04 - São Caetano               18                               0
# 21        AISP 05 - Periperi               44                               1
# 22             AISP 08 - CIA               10                               0
# 23                  RISP BTS              141                               1
# 24     AISP 10 - Pau da Lima               20                               0
# 25  AISP 11 - Tancredo Neves               37                               0
# 26      AISP 13 - Cajazeiras               18                               0
# 27              RISP CENTRAL               75                               0
# 28          TOTAL DA CAPITAL              284                               1
#
#    latrocínio tentativa de homicídio estupro roubo a ônibus roubo de veículo  \
# 9           4                     43      21            205              568
# 10          3                     13      21            106              287
# 11          1                     12      13             57              562
# 12          8                     44      62            168              832
# 13          0                      1       5             33               80
# 14          0                      6      12             61               20
# 15          0                     10       7            114              358
# 16         16                    129     141            744            2.707
# 17          4                     18      22            107              291
# 18          3                     56      35             93              545
# 19          3                     54      27            125              372
# 20          7                     26      55            149              431
# 21          6                    156      82            175              395
# 22          1                      7       6             12              147
# 23         24                    317     227            661            2.181
# 24          4                     64      35            147              533
# 25          5                    125      86            333              713
# 26          1                     77      43             44              239
# 27         10                    266     164            524            1.485
# 28         50                    712     532          1.929            6.373
# 9           5                     22      31            190              493
# 10          1                     33      18            153              241
# 11          4                     25      31             49              596
# 12          6                     18      49            218              871
# 13          2                      4       9             28               82
# 14          2                     15       9             69               17
# 15          1                      5      10             84              380
# 16         21                    122     157            791            2.680
# 17          5                     37      22            159              293
# 18          1                     48      32            143              496
# ..        ...                    ...     ...            ...              ...
# 19          4                     46      52            327              282
# 20          4                     43      39            289              489
# 21          5                     96      82            342              423
# 22          0                     14       6             38              134
# 23         16                    300     227          1.269            1.996
# 24          3                     32      48             87              495
# 25          4                     49      84            347              629
# 26          4                     21      48             85              366
# 27         11                    102     180            519            1.490
# 28         36                    523     576          2.615            5.733
# 9           1                      9       0             34               90
# 10          0                      5       2             27               57
# 11          0                      1       5             14              122
# 12          0                      3       3             11              138
# 13          0                      0       0              4               10
# 14          0                      3       2              7                5
# 15          0                      0       0             34               62
# 16          1                     21      12            131              484
# 17          0                      9       4             13               55
# 18          0                     12       3             21              133
# 19          0                     14       9             35               78
# 20          0                      2      12             58              155
# 21          1                     17      10             58               82
# 22          0                      1       2             15               40
# 23          1                     55      40            200              543
# 24          0                      3       7             27              124
# 25          0                      6       8             79              170
# 26          0                      6       4             34              104
# 27          0                     15      19            140              398
# 28          2                     91      71            471            1.425
#
#    furto de veículo uso/porte substância entorpecente    ano
# 9               150                                 74  2014
# 10               63                                107  2014
# 11               64                                 24  2014
# 12              234                                132  2014
# 13               28                                 35  2014
# 14                7                                 33  2014
# 15               38                                 31  2014
# 16              584                                436  2014
# 17              120                                119  2014
# 18              191                                 56  2014
# 19              246                                 65  2014
# 20               85                                 37  2014
# 21               70                                 52  2014
# 22               22                                  9  2014
# 23              734                                338  2014
# 24              160                                 35  2014
# 25              219                                103  2014
# 26               55                                 18  2014
# 27              434                                156  2014
# 28            1.752                                930  2014
# 9               133                                 77  2015
# 10               58                                 41  2015
# 11               67                                 90  2015
# 12              189                                 79  2015
# 13               14                                 47  2015
# 14               14                                 57  2015
# 15               38                                 52  2015
# 16              513                                443  2015
# 17              126                                 85  2015
# 18              149                                 21  2015
# ..              ...                                ...   ...
# 19              191                                 93  2017
# 20               92                                 55  2017
# 21               81                                104  2017
# 22                9                                111  2017
# 23              566                                554  2017
# 24              137                                 23  2017
# 25              209                                230  2017
# 26               50                                 79  2017
# 27              396                                332  2017
# 28            1.565                              1.533  2017
# 9                22                                 16  2018
# 10               24                                 41  2018
# 11               29                                 26  2018
# 12               56                                  4  2018
# 13                5                                 15  2018
# 14                3                                 19  2018
# 15               20                                 23  2018
# 16              159                                144  2018
# 17               13                                 69  2018
# 18               16                                 12  2018
# 19               42                                 22  2018
# 20               16                                 15  2018
# 21               24                                 12  2018
# 22                3                                 28  2018
# 23              114                                158  2018
# 24               32                                  6  2018
# 25               31                                 34  2018
# 26               16                                 13  2018
# 27               79                                 53  2018
# 28              352                                355  2018
#
# [100 rows x 11 columns]

# %% [markdown]
# <h3 style="color: #f44336;">Resumo - Limpeza de Dados</h3>
# <ul>
#     <li>Após ter carregado e identificado os valores/variaveis de todos os dataset podemos perceber que existima muitas linhas com valores vazios devido a falhas na conversão do arquivo</li>
#     <li>Todas as linhas com valores vazios foram devidamente excluídas</li>
#     <li>Para melhorar a leitura foram incluídos novos nomes/titulos as colunas dos datasets</li>
#     <li>Outro item de melhoria para a leitura foi a criação da coluna ano e a combinação de todos os datasets em um único dataset total</li>
# </ul>

# %% [markdown]
# <h2 style="color: #f44336;">Vamos as perguntas</h2>

# %% [markdown]
# Qual o valor total por tipo de crime e dividido por ano?

# %%
#Ano 2014
ano = 2014
total2014 = ds_total.query('ano == 2014 and aisp == "TOTAL DA CAPITAL"')
lista2014 = [total2014['homicídio doloso'].unique()[0], total2014['lesão corporal seguida de morte'].unique()[0], 
             total2014['latrocínio'].unique()[0], total2014['tentativa de homicídio'].unique()[0], 
             total2014['estupro'].unique()[0], total2014['roubo a ônibus'].unique()[0], total2014['roubo a ônibus'].unique()[0],
             total2014['roubo de veículo'].unique()[0], total2014['furto de veículo'].unique()[0]]
float(lista2014[8])
# Out:
# 1.752

# %%
locations = [1, 2, 3, 4, 5, 6, 7, 8]
heights = [float(lista2014[0]), float(lista2014[1]), float(lista2014[2]), float(lista2014[3]), float(lista2014[4]), float(lista2014[5]),
          float(lista2014[6]), float(lista2014[7])]
labels = ['Homicídio Doloso', 'Lesão Corporal Seguida de Morte', 'Latrocínio', 'Tentativa de Homicídio', 'Estupro', 
          'Roubo de Ônibus', 'Roubo de Veículo', 'Furto de Veículo']
colors = ['blue', 'red', 'orange', 'gray', 'green', 'yellow', 'black', 'teal']
plt.barh(locations, heights, align='center', color= colors, ecolor='black',tick_label=labels )
plt.title('Estatisticas dos Crimes em Salvador')
plt.xlabel('Modalidades de Crimes')
plt.ylabel('Quantidade de Registros')
plt.width = 1.0
plt.legend( labels, fontsize=12)
